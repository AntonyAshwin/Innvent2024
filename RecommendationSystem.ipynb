# %%
import pandas as pd

# %%
import datetime

# %%
from pulp import LpMaximize, LpProblem, LpVariable, lpSum, LpStatus

# %%
start_date = '2023-01-01'
end_date = '2023-01-20'
assortment_key = 'MD1'
product_count = 6
shelf_height = 100  # cm
shelf_width = 50    # cm
shelf_depth = 30    # cm (optional)
shelf_volume = shelf_height * shelf_width * shelf_depth  # cm^3

# %%
# Read the Excel files
rule_type_1_df = pd.read_excel('bsnrules.xlsx')
result = pd.read_excel('rankingkey.xlsx')

# Remove duplicates from the result DataFrame
result = result.drop_duplicates()

# Create an empty DataFrame to store the final results
final_df = pd.DataFrame()

# Iterate through each rule in rule_type_1_df
for idx, rule in rule_type_1_df.iterrows():
    # Filter the result DataFrame based on the Assortment Key
    matching_products = result[result['Assortment Key'] == rule['Product']]
    
    # For each matching product, create a new rule with the product name
    for _, product in matching_products.iterrows():
        new_rule = rule.copy()
        new_rule['Product'] = product['Product']
        final_df = pd.concat([final_df, new_rule.to_frame().T], ignore_index=True)

# Reset index of the final DataFrame
final_df.reset_index(drop=True, inplace=True)

# %%
rule_type_1_df
# Out:
#    Rule ID                      Product                 Attribute Operator  \
# 0        1                     Sunfeast            Sales per Week        >
# 1        2             Alphonso Mangoes      Retail Cost per Week        <
# 2        3                    Britannia            Sales per Week       >=
# 3        4     Minute Maid Orange Juice  Production Cost per Week       <=
# 4        5             REAL Guava Juice      Retail Cost per Week        >
# 5        6                 Unibic Foods            Sales per Week        <
# 6        7                       Maaza       Retail Cost per Week       >=
# 7        8  Tropicano Pomegranate Juice  Production Cost per Week       <=
# 8        9                        Parle            Sales per Week        >
# 9       10                          MD1  Production Cost per Week        <
#
#    Value  RULE_TYPE
# 0    100          0
# 1   3500          0
# 2    150          0
# 3   3000          0
# 4   2000          0
# 5    200          0
# 6   5000          0
# 7   2000          0
# 8    120          0
# 9   1700          1

# %%
final_df = final_df.drop_duplicates()

# %%
rules = pd.concat([rule_type_1_df, final_df], ignore_index=True)

# %%
rules
# Out:
#    Rule ID                      Product                 Attribute Operator  \
# 0        1                     Sunfeast            Sales per Week        >
# 1        2             Alphonso Mangoes      Retail Cost per Week        <
# 2        3                    Britannia            Sales per Week       >=
# 3        4     Minute Maid Orange Juice  Production Cost per Week       <=
# 4        5             REAL Guava Juice      Retail Cost per Week        >
# 5        6                 Unibic Foods            Sales per Week        <
# 6        7                       Maaza       Retail Cost per Week       >=
# 7        8  Tropicano Pomegranate Juice  Production Cost per Week       <=
# 8        9                        Parle            Sales per Week        >
# 9       10                          MD1  Production Cost per Week        <
# 10      10   BNatural Pomegranate Juice  Production Cost per Week        <
# 11      10       Real Pomegranate Juice  Production Cost per Week        <
# 12      10  Tropicano Pomegranate Juice  Production Cost per Week        <
# 13      10     Minute Maid Orange Juice  Production Cost per Week        <
# 14      10             REAL Guava Juice  Production Cost per Week        <
# 15      10        Tropicano Guava Juice  Production Cost per Week        <
# 16      10                       Maaza   Production Cost per Week        <
# 17      10        Parle Agros Appy Fizz  Production Cost per Week        <
#
#    Value RULE_TYPE
# 0    100         0
# 1   3500         0
# 2    150         0
# 3   3000         0
# 4   2000         0
# 5    200         0
# 6   5000         0
# 7   2000         0
# 8    120         0
# 9   1700         1
# 10  1700         1
# 11  1700         1
# 12  1700         1
# 13  1700         1
# 14  1700         1
# 15  1700         1
# 16  1700         1
# 17  1700         1

# %%
df = pd.read_excel('rankingkey.xlsx')

# %%
df
# Out:
#                         Product  Sales per Week  Retail Cost per Week  \
# 0    BNatural Pomegranate Juice             150                  3000
# 1        Real Pomegranate Juice             200                  4000
# 2                      Horlicks             100                  2500
# 3              Alphonso Mangoes             180                  5400
# 4                         Parle             130                  2600
# ..                          ...             ...                   ...
# 163                  Strawberry             210                  3500
# 164                   Cranberry             200                  4600
# 165                  Gala Apple             240                  5800
# 166                      Maaza              230                  5500
# 167       Parle Agros Appy Fizz             270                  9700
#
#      Production Cost per Week Product ID Assortment Key  Week   Validity
# 0                        1800       P001            MD1     1 2023-01-01
# 1                        2500       P002            MD1     1 2023-01-01
# 2                        1400       P003            MD3     1 2023-01-01
# 3                        3200       P004            MD2     1 2023-01-01
# 4                        1600       P005            MD3     1 2023-01-01
# ..                        ...        ...            ...   ...        ...
# 163                      2050       P017            MD2     8 2023-02-19
# 164                      2750       P018            MD2     8 2023-02-19
# 165                      3450       P019            MD2     8 2023-02-19
# 166                      3150       P020            MD1     8 2023-02-19
# 167                      1350       P021            MD1     8 2023-02-19
#
# [168 rows x 8 columns]

# %%
mask = (df['Validity'] >= start_date) & (df['Validity'] <= end_date) & (df['Assortment Key'] == assortment_key)

# %%
df2 = df[mask]

# %%
df2
# Out:
#                         Product  Sales per Week  Retail Cost per Week  \
# 0    BNatural Pomegranate Juice             150                  3000
# 1        Real Pomegranate Juice             200                  4000
# 6   Tropicano Pomegranate Juice             140                  2800
# 9      Minute Maid Orange Juice             210                  6300
# 10             REAL Guava Juice             170                  3400
# 15        Tropicano Guava Juice             200                  6000
# 19                       Maaza              160                  4800
# 20        Parle Agros Appy Fizz             200                  9000
# 21   BNatural Pomegranate Juice             160                  3100
# 22       Real Pomegranate Juice             210                  4100
# 27  Tropicano Pomegranate Juice             150                  2900
# 30     Minute Maid Orange Juice             220                  6400
# 31             REAL Guava Juice             180                  3500
# 36        Tropicano Guava Juice             210                  6100
# 40                       Maaza              170                  4900
# 41        Parle Agros Appy Fizz             210                  9100
# 42   BNatural Pomegranate Juice             170                  3200
# 43       Real Pomegranate Juice             220                  4200
# 48  Tropicano Pomegranate Juice             160                  3000
# 51     Minute Maid Orange Juice             230                  6500
# 52             REAL Guava Juice             190                  3600
# 57        Tropicano Guava Juice             220                  6200
# 61                       Maaza              180                  5000
# 62        Parle Agros Appy Fizz             220                  9200
#
#     Production Cost per Week Product ID Assortment Key  Week   Validity
# 0                       1800       P001            MD1     1 2023-01-01
# 1                       2500       P002            MD1     1 2023-01-01
# 6                       1700       P007            MD1     1 2023-01-01
# 9                       3800       P010            MD1     1 2023-01-01
# 10                      2200       P011            MD1     1 2023-01-01
# 15                      3600       P016            MD1     1 2023-01-01
# 19                      2800       P020            MD1     1 2023-01-01
# 20                      1000       P021            MD1     1 2023-01-01
# 21                      1850       P001            MD1     2 2023-01-08
# 22                      2550       P002            MD1     2 2023-01-08
# 27                      1750       P007            MD1     2 2023-01-08
# 30                      3850       P010            MD1     2 2023-01-08
# 31                      2250       P011            MD1     2 2023-01-08
# 36                      3650       P016            MD1     2 2023-01-08
# 40                      2850       P020            MD1     2 2023-01-08
# 41                      1050       P021            MD1     2 2023-01-08
# 42                      1900       P001            MD1     3 2023-01-15
# 43                      2600       P002            MD1     3 2023-01-15
# 48                      1800       P007            MD1     3 2023-01-15
# 51                      3900       P010            MD1     3 2023-01-15
# 52                      2300       P011            MD1     3 2023-01-15
# 57                      3700       P016            MD1     3 2023-01-15
# 61                      2900       P020            MD1     3 2023-01-15
# 62                      1100       P021            MD1     3 2023-01-15

# %%
df2["(K,D,O)"] = "D"
# Out:
# /var/folders/fs/zvq11zm97ps2908z0gl0wpyr0000gn/T/ipykernel_56952/2536967661.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["(K,D,O)"] = "D"

# %%
df2
# Out:
#                         Product  Sales per Week  Retail Cost per Week  \
# 0    BNatural Pomegranate Juice             150                  3000
# 1        Real Pomegranate Juice             200                  4000
# 6   Tropicano Pomegranate Juice             140                  2800
# 9      Minute Maid Orange Juice             210                  6300
# 10             REAL Guava Juice             170                  3400
# 15        Tropicano Guava Juice             200                  6000
# 19                       Maaza              160                  4800
# 20        Parle Agros Appy Fizz             200                  9000
# 21   BNatural Pomegranate Juice             160                  3100
# 22       Real Pomegranate Juice             210                  4100
# 27  Tropicano Pomegranate Juice             150                  2900
# 30     Minute Maid Orange Juice             220                  6400
# 31             REAL Guava Juice             180                  3500
# 36        Tropicano Guava Juice             210                  6100
# 40                       Maaza              170                  4900
# 41        Parle Agros Appy Fizz             210                  9100
# 42   BNatural Pomegranate Juice             170                  3200
# 43       Real Pomegranate Juice             220                  4200
# 48  Tropicano Pomegranate Juice             160                  3000
# 51     Minute Maid Orange Juice             230                  6500
# 52             REAL Guava Juice             190                  3600
# 57        Tropicano Guava Juice             220                  6200
# 61                       Maaza              180                  5000
# 62        Parle Agros Appy Fizz             220                  9200
#
#     Production Cost per Week Product ID Assortment Key  Week   Validity  \
# 0                       1800       P001            MD1     1 2023-01-01
# 1                       2500       P002            MD1     1 2023-01-01
# 6                       1700       P007            MD1     1 2023-01-01
# 9                       3800       P010            MD1     1 2023-01-01
# 10                      2200       P011            MD1     1 2023-01-01
# 15                      3600       P016            MD1     1 2023-01-01
# 19                      2800       P020            MD1     1 2023-01-01
# 20                      1000       P021            MD1     1 2023-01-01
# 21                      1850       P001            MD1     2 2023-01-08
# 22                      2550       P002            MD1     2 2023-01-08
# 27                      1750       P007            MD1     2 2023-01-08
# 30                      3850       P010            MD1     2 2023-01-08
# 31                      2250       P011            MD1     2 2023-01-08
# 36                      3650       P016            MD1     2 2023-01-08
# 40                      2850       P020            MD1     2 2023-01-08
# 41                      1050       P021            MD1     2 2023-01-08
# 42                      1900       P001            MD1     3 2023-01-15
# 43                      2600       P002            MD1     3 2023-01-15
# 48                      1800       P007            MD1     3 2023-01-15
# 51                      3900       P010            MD1     3 2023-01-15
# 52                      2300       P011            MD1     3 2023-01-15
# 57                      3700       P016            MD1     3 2023-01-15
# 61                      2900       P020            MD1     3 2023-01-15
# 62                      1100       P021            MD1     3 2023-01-15
#
#    (K,D,O)
# 0        D
# 1        D
# 6        D
# 9        D
# 10       D
# 15       D
# 19       D
# 20       D
# 21       D
# 22       D
# 27       D
# 30       D
# 31       D
# 36       D
# 40       D
# 41       D
# 42       D
# 43       D
# 48       D
# 51       D
# 52       D
# 57       D
# 61       D
# 62       D

# %%
df2.shape
# Out:
# (24, 9)

# %%
df2["Product"].unique()
# Out:
# array(['BNatural Pomegranate Juice', 'Real Pomegranate Juice',
#        'Tropicano Pomegranate Juice', 'Minute Maid Orange Juice',
#        'REAL Guava Juice', 'Tropicano Guava Juice', 'Maaza ',
#        'Parle Agros Appy Fizz'], dtype=object)

# %%
agg_functions = {'Sales per Week': 'mean',
                 'Retail Cost per Week': 'mean',
                 'Production Cost per Week': 'mean',
                 'Product': 'first',
                 'Assortment Key': 'first',
                 'Week': 'first',
                 'Validity': 'first',
                 '(K,D,O)': 'first'}

# %%
df2_agg = df2.groupby('Product').agg(agg_functions)

# %%
df2_agg
# Out:
#                              Sales per Week  Retail Cost per Week  \
# Product
# BNatural Pomegranate Juice            160.0                3100.0
# Maaza                                 170.0                4900.0
# Minute Maid Orange Juice              220.0                6400.0
# Parle Agros Appy Fizz                 210.0                9100.0
# REAL Guava Juice                      180.0                3500.0
# Real Pomegranate Juice                210.0                4100.0
# Tropicano Guava Juice                 210.0                6100.0
# Tropicano Pomegranate Juice           150.0                2900.0
#
#                              Production Cost per Week  \
# Product
# BNatural Pomegranate Juice                     1850.0
# Maaza                                          2850.0
# Minute Maid Orange Juice                       3850.0
# Parle Agros Appy Fizz                          1050.0
# REAL Guava Juice                               2250.0
# Real Pomegranate Juice                         2550.0
# Tropicano Guava Juice                          3650.0
# Tropicano Pomegranate Juice                    1750.0
#
#                                                  Product Assortment Key  Week  \
# Product
# BNatural Pomegranate Juice    BNatural Pomegranate Juice            MD1     1
# Maaza                                             Maaza             MD1     1
# Minute Maid Orange Juice        Minute Maid Orange Juice            MD1     1
# Parle Agros Appy Fizz              Parle Agros Appy Fizz            MD1     1
# REAL Guava Juice                        REAL Guava Juice            MD1     1
# Real Pomegranate Juice            Real Pomegranate Juice            MD1     1
# Tropicano Guava Juice              Tropicano Guava Juice            MD1     1
# Tropicano Pomegranate Juice  Tropicano Pomegranate Juice            MD1     1
#
#                               Validity (K,D,O)
# Product
# BNatural Pomegranate Juice  2023-01-01       D
# Maaza                       2023-01-01       D
# Minute Maid Orange Juice    2023-01-01       D
# Parle Agros Appy Fizz       2023-01-01       D
# REAL Guava Juice            2023-01-01       D
# Real Pomegranate Juice      2023-01-01       D
# Tropicano Guava Juice       2023-01-01       D
# Tropicano Pomegranate Juice 2023-01-01       D

# %%
df2_agg
# Out:
#                              Sales per Week  Retail Cost per Week  \
# Product
# BNatural Pomegranate Juice            160.0                3100.0
# Maaza                                 170.0                4900.0
# Minute Maid Orange Juice              220.0                6400.0
# Parle Agros Appy Fizz                 210.0                9100.0
# REAL Guava Juice                      180.0                3500.0
# Real Pomegranate Juice                210.0                4100.0
# Tropicano Guava Juice                 210.0                6100.0
# Tropicano Pomegranate Juice           150.0                2900.0
#
#                              Production Cost per Week  \
# Product
# BNatural Pomegranate Juice                     1850.0
# Maaza                                          2850.0
# Minute Maid Orange Juice                       3850.0
# Parle Agros Appy Fizz                          1050.0
# REAL Guava Juice                               2250.0
# Real Pomegranate Juice                         2550.0
# Tropicano Guava Juice                          3650.0
# Tropicano Pomegranate Juice                    1750.0
#
#                                                  Product Assortment Key  Week  \
# Product
# BNatural Pomegranate Juice    BNatural Pomegranate Juice            MD1     1
# Maaza                                             Maaza             MD1     1
# Minute Maid Orange Juice        Minute Maid Orange Juice            MD1     1
# Parle Agros Appy Fizz              Parle Agros Appy Fizz            MD1     1
# REAL Guava Juice                        REAL Guava Juice            MD1     1
# Real Pomegranate Juice            Real Pomegranate Juice            MD1     1
# Tropicano Guava Juice              Tropicano Guava Juice            MD1     1
# Tropicano Pomegranate Juice  Tropicano Pomegranate Juice            MD1     1
#
#                               Validity (K,D,O)
# Product
# BNatural Pomegranate Juice  2023-01-01       D
# Maaza                       2023-01-01       D
# Minute Maid Orange Juice    2023-01-01       D
# Parle Agros Appy Fizz       2023-01-01       D
# REAL Guava Juice            2023-01-01       D
# Real Pomegranate Juice      2023-01-01       D
# Tropicano Guava Juice       2023-01-01       D
# Tropicano Pomegranate Juice 2023-01-01       D

# %%
for index, row in rules.iterrows():
    product = row['Product']
    attribute = row['Attribute']
    operator = row['Operator']
    value = row['Value']
 
 
    if product in df['Product'].values:
 
        condition_met = False
        product_row = df[df['Product'] == product].iloc[0]
        print(product_row)
        print("--------------")
        print(product_row[attribute],operator,  value)
 
 
        if operator == '>':
            condition_met = product_row[attribute] > value
            print(condition_met)
        elif operator == '<':
            condition_met = product_row[attribute] < value
            print(condition_met)
        elif operator == '>=':
            condition_met = product_row[attribute] >= value
            print(condition_met)
        elif operator == '<=':
            condition_met = product_row[attribute] <= value
            print(condition_met)
        elif operator == '==':
            condition_met = product_row[attribute] == value
            print(condition_met)
 
        if condition_met:
            print(f"{product}: BR satisfied")
            print(product)
            print("=======================")
        else:
            print(f"{product}: BR unsatisfied")
            print(product)
            df.loc[df["Product"] == product, "(K,D,O)"] = "O"
            print("=======================")
 
    else:
        print(f"{product}: Product not found in df DataFrame")
# Out:
# Product                                Sunfeast
# Sales per Week                              160
# Retail Cost per Week                       4800
# Production Cost per Week                   2900
# Product ID                                 P009
# Assortment Key                              MD3
# Week                                          1
# Validity                    2023-01-01 00:00:00
# Name: 8, dtype: object
# --------------
# 160     > 100
# Sunfeast: BR unsatisfied
# Sunfeast
# =======================
# Product                        Alphonso Mangoes
# Sales per Week                              180
# Retail Cost per Week                       5400
# Production Cost per Week                   3200
# Product ID                                 P004
# Assortment Key                              MD2
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       n
# Name: 3, dtype: object
# --------------
# 5400 < 3500
# False
# Alphonso Mangoes: BR unsatisfied
# Alphonso Mangoes
# =======================
# Product                               Britannia
# Sales per Week                              220
# Retail Cost per Week                       6600
# Production Cost per Week                   4100
# Product ID                                 P006
# Assortment Key                              MD3
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       n
# Name: 5, dtype: object
# --------------
# 220     >= 150
# Britannia: BR unsatisfied
# Britannia
# =======================
# Product                     Minute Maid Orange Juice
# Sales per Week                                   210
# Retail Cost per Week                            6300
# Production Cost per Week                        3800
# Product ID                                      P010
# Assortment Key                                   MD1
# Week                                               1
# Validity                         2023-01-01 00:00:00
# (K,D,O)                                            n
# Name: 9, dtype: object
# --------------
# 3800 <= 3000
# False
# Minute Maid Orange Juice: BR unsatisfied
# Minute Maid Orange Juice
# =======================
# Product                        REAL Guava Juice
# Sales per Week                              170
# Retail Cost per Week                       3400
# Production Cost per Week                   2200
# Product ID                                 P011
# Assortment Key                              MD1
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       n
# Name: 10, dtype: object
# --------------
# 3400 > 2000
# True
# REAL Guava Juice: BR satisfied
# REAL Guava Juice
# =======================
# Product                            Unibic Foods
# Sales per Week                              150
# Retail Cost per Week                       4500
# Production Cost per Week                   2700
# Product ID                                 P013
# Assortment Key                              MD3
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       n
# Name: 12, dtype: object
# --------------
# 150     < 200
# Unibic Foods: BR unsatisfied
# Unibic Foods
# =======================
# Product                                  Maaza
# Sales per Week                              160
# Retail Cost per Week                       4800
# Production Cost per Week                   2800
# Product ID                                 P020
# Assortment Key                              MD1
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       n
# Name: 19, dtype: object
# --------------
# 4800 >= 5000
# False
# Maaza : BR unsatisfied
# Maaza
# =======================
# Product                     Tropicano Pomegranate Juice
# Sales per Week                                      140
# Retail Cost per Week                               2800
# Production Cost per Week                           1700
# Product ID                                         P007
# Assortment Key                                      MD1
# Week                                                  1
# Validity                            2023-01-01 00:00:00
# (K,D,O)                                               n
# Name: 6, dtype: object
# --------------
# 1700 <= 2000
# True
# Tropicano Pomegranate Juice: BR satisfied
# Tropicano Pomegranate Juice
# =======================
# Product                                   Parle
# Sales per Week                              130
# Retail Cost per Week                       2600
# Production Cost per Week                   1600
# Product ID                                 P005
# Assortment Key                              MD3
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       n
# Name: 4, dtype: object
# --------------
# 130     > 120
# Parle: BR unsatisfied
# Parle
# =======================
# MD1: Product not found in df DataFrame
# Product                     BNatural Pomegranate Juice
# Sales per Week                                     150
# Retail Cost per Week                              3000
# Production Cost per Week                          1800
# Product ID                                        P001
# Assortment Key                                     MD1
# Week                                                 1
# Validity                           2023-01-01 00:00:00
# (K,D,O)                                              n
# Name: 0, dtype: object
# --------------
# 1800 < 1700
# False
# BNatural Pomegranate Juice: BR unsatisfied
# BNatural Pomegranate Juice
# =======================
# Product                     Real Pomegranate Juice
# Sales per Week                                 200
# Retail Cost per Week                          4000
# Production Cost per Week                      2500
# Product ID                                    P002
# Assortment Key                                 MD1
# Week                                             1
# Validity                       2023-01-01 00:00:00
# (K,D,O)                                          n
# Name: 1, dtype: object
# --------------
# 2500 < 1700
# False
# Real Pomegranate Juice: BR unsatisfied
# Real Pomegranate Juice
# =======================
# Product                     Tropicano Pomegranate Juice
# Sales per Week                                      140
# Retail Cost per Week                               2800
# Production Cost per Week                           1700
# Product ID                                         P007
# Assortment Key                                      MD1
# Week                                                  1
# Validity                            2023-01-01 00:00:00
# (K,D,O)                                               n
# Name: 6, dtype: object
# --------------
# 1700 < 1700
# False
# Tropicano Pomegranate Juice: BR unsatisfied
# Tropicano Pomegranate Juice
# =======================
# Product                     Minute Maid Orange Juice
# Sales per Week                                   210
# Retail Cost per Week                            6300
# Production Cost per Week                        3800
# Product ID                                      P010
# Assortment Key                                   MD1
# Week                                               1
# Validity                         2023-01-01 00:00:00
# (K,D,O)                                            O
# Name: 9, dtype: object
# --------------
# 3800 < 1700
# False
# Minute Maid Orange Juice: BR unsatisfied
# Minute Maid Orange Juice
# =======================
# Product                        REAL Guava Juice
# Sales per Week                              170
# Retail Cost per Week                       3400
# Production Cost per Week                   2200
# Product ID                                 P011
# Assortment Key                              MD1
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       n
# Name: 10, dtype: object
# --------------
# 2200 < 1700
# False
# REAL Guava Juice: BR unsatisfied
# REAL Guava Juice
# =======================
# Product                     Tropicano Guava Juice
# Sales per Week                                200
# Retail Cost per Week                         6000
# Production Cost per Week                     3600
# Product ID                                   P016
# Assortment Key                                MD1
# Week                                            1
# Validity                      2023-01-01 00:00:00
# (K,D,O)                                         n
# Name: 15, dtype: object
# --------------
# 3600 < 1700
# False
# Tropicano Guava Juice: BR unsatisfied
# Tropicano Guava Juice
# =======================
# Product                                  Maaza
# Sales per Week                              160
# Retail Cost per Week                       4800
# Production Cost per Week                   2800
# Product ID                                 P020
# Assortment Key                              MD1
# Week                                          1
# Validity                    2023-01-01 00:00:00
# (K,D,O)                                       O
# Name: 19, dtype: object
# --------------
# 2800 < 1700
# False
# Maaza : BR unsatisfied
# Maaza
# =======================
# Product                     Parle Agros Appy Fizz
# Sales per Week                                200
# Retail Cost per Week                         9000
# Production Cost per Week                     1000
# Product ID                                   P021
# Assortment Key                                MD1
# Week                                            1
# Validity                      2023-01-01 00:00:00
# (K,D,O)                                         n
# Name: 20, dtype: object
# --------------
# 1000 < 1700
# True
# Parle Agros Appy Fizz: BR satisfied
# Parle Agros Appy Fizz
# =======================

# %%
df2_agg
# Out:
#                              Sales per Week  Retail Cost per Week  \
# Product
# BNatural Pomegranate Juice            160.0                3100.0
# Maaza                                 170.0                4900.0
# Minute Maid Orange Juice              220.0                6400.0
# Parle Agros Appy Fizz                 210.0                9100.0
# REAL Guava Juice                      180.0                3500.0
# Real Pomegranate Juice                210.0                4100.0
# Tropicano Guava Juice                 210.0                6100.0
# Tropicano Pomegranate Juice           150.0                2900.0
#
#                              Production Cost per Week  \
# Product
# BNatural Pomegranate Juice                     1850.0
# Maaza                                          2850.0
# Minute Maid Orange Juice                       3850.0
# Parle Agros Appy Fizz                          1050.0
# REAL Guava Juice                               2250.0
# Real Pomegranate Juice                         2550.0
# Tropicano Guava Juice                          3650.0
# Tropicano Pomegranate Juice                    1750.0
#
#                                                  Product Assortment Key  Week  \
# Product
# BNatural Pomegranate Juice    BNatural Pomegranate Juice            MD1     1
# Maaza                                             Maaza             MD1     1
# Minute Maid Orange Juice        Minute Maid Orange Juice            MD1     1
# Parle Agros Appy Fizz              Parle Agros Appy Fizz            MD1     1
# REAL Guava Juice                        REAL Guava Juice            MD1     1
# Real Pomegranate Juice            Real Pomegranate Juice            MD1     1
# Tropicano Guava Juice              Tropicano Guava Juice            MD1     1
# Tropicano Pomegranate Juice  Tropicano Pomegranate Juice            MD1     1
#
#                               Validity (K,D,O)
# Product
# BNatural Pomegranate Juice  2023-01-01       D
# Maaza                       2023-01-01       D
# Minute Maid Orange Juice    2023-01-01       D
# Parle Agros Appy Fizz       2023-01-01       D
# REAL Guava Juice            2023-01-01       D
# Real Pomegranate Juice      2023-01-01       D
# Tropicano Guava Juice       2023-01-01       D
# Tropicano Pomegranate Juice 2023-01-01       D

# %%
# normalizing

df2_agg['Normalized Sales'] = (df2_agg['Sales per Week'] - df2_agg['Sales per Week'].min()) / (df2_agg['Sales per Week'].max() - df2_agg['Sales per Week'].min())
df2_agg['Profit'] = df2_agg['Retail Cost per Week'] - df2_agg['Production Cost per Week']
df2_agg['Normalized Profit'] = (df2_agg['Profit'] - df2_agg['Profit'].min()) / (df2_agg['Profit'].max() - df2_agg['Profit'].min())

#ranking key here
df2_agg['Ranking Key'] = 0.5 * df2_agg['Normalized Sales'] + 0.5 * df2_agg['Normalized Profit']


def get_top_products(product_count):
   
    sorted_df = df2_agg.sort_values(by='Ranking Key', ascending=False)
   
    top_products = sorted_df.head(product_count)
    return top_products

#product count im taking as a number for now 



top_products = get_top_products(product_count)

print(top_products[['Product', 'Sales per Week', 'Retail Cost per Week', 'Production Cost per Week', 'Ranking Key']])
# Out:
#                                            Product  Sales per Week  \
# Product
# Parle Agros Appy Fizz        Parle Agros Appy Fizz           210.0
# Minute Maid Orange Juice  Minute Maid Orange Juice           220.0
# Tropicano Guava Juice        Tropicano Guava Juice           210.0
# Real Pomegranate Juice      Real Pomegranate Juice           210.0
# REAL Guava Juice                  REAL Guava Juice           180.0
# Maaza                                       Maaza            170.0
#
#                           Retail Cost per Week  Production Cost per Week  \
# Product
# Parle Agros Appy Fizz                   9100.0                    1050.0
# Minute Maid Orange Juice                6400.0                    3850.0
# Tropicano Guava Juice                   6100.0                    3650.0
# Real Pomegranate Juice                  4100.0                    2550.0
# REAL Guava Juice                        3500.0                    2250.0
# Maaza                                   4900.0                    2850.0
#
#                           Ranking Key
# Product
# Parle Agros Appy Fizz        0.928571
# Minute Maid Orange Juice     0.601449
# Tropicano Guava Juice        0.522774
# Real Pomegranate Juice       0.457557
# REAL Guava Juice             0.221532
# Maaza                        0.208075

# %%
top_products
# Out:
#                           Sales per Week  Retail Cost per Week  \
# Product
# Parle Agros Appy Fizz              210.0                9100.0
# Minute Maid Orange Juice           220.0                6400.0
# Tropicano Guava Juice              210.0                6100.0
# Real Pomegranate Juice             210.0                4100.0
# REAL Guava Juice                   180.0                3500.0
# Maaza                              170.0                4900.0
#
#                           Production Cost per Week                   Product  \
# Product
# Parle Agros Appy Fizz                       1050.0     Parle Agros Appy Fizz
# Minute Maid Orange Juice                    3850.0  Minute Maid Orange Juice
# Tropicano Guava Juice                       3650.0     Tropicano Guava Juice
# Real Pomegranate Juice                      2550.0    Real Pomegranate Juice
# REAL Guava Juice                            2250.0          REAL Guava Juice
# Maaza                                       2850.0                    Maaza
#
#                          Assortment Key  Week   Validity (K,D,O)  \
# Product
# Parle Agros Appy Fizz               MD1     1 2023-01-01       D
# Minute Maid Orange Juice            MD1     1 2023-01-01       D
# Tropicano Guava Juice               MD1     1 2023-01-01       D
# Real Pomegranate Juice              MD1     1 2023-01-01       D
# REAL Guava Juice                    MD1     1 2023-01-01       D
# Maaza                               MD1     1 2023-01-01       D
#
#                           Normalized Sales  Profit  Normalized Profit  \
# Product
# Parle Agros Appy Fizz             0.857143  8050.0           1.000000
# Minute Maid Orange Juice          1.000000  2550.0           0.202899
# Tropicano Guava Juice             0.857143  2450.0           0.188406
# Real Pomegranate Juice            0.857143  1550.0           0.057971
# REAL Guava Juice                  0.428571  1250.0           0.014493
# Maaza                             0.285714  2050.0           0.130435
#
#                           Ranking Key
# Product
# Parle Agros Appy Fizz        0.928571
# Minute Maid Orange Juice     0.601449
# Tropicano Guava Juice        0.522774
# Real Pomegranate Juice       0.457557
# REAL Guava Juice             0.221532
# Maaza                        0.208075

# %%
mask = df2_agg['Product'].isin(top_products['Product'])

# %%
df2_agg.loc[mask, "(K,D,O)"] = df2_agg.loc[mask, "(K,D,O)"].apply(lambda x: "K")

# %%
df2_agg.head(30)
# Out:
#                              Sales per Week  Retail Cost per Week  \
# Product
# BNatural Pomegranate Juice            160.0                3100.0
# Maaza                                 170.0                4900.0
# Minute Maid Orange Juice              220.0                6400.0
# Parle Agros Appy Fizz                 210.0                9100.0
# REAL Guava Juice                      180.0                3500.0
# Real Pomegranate Juice                210.0                4100.0
# Tropicano Guava Juice                 210.0                6100.0
# Tropicano Pomegranate Juice           150.0                2900.0
#
#                              Production Cost per Week  \
# Product
# BNatural Pomegranate Juice                     1850.0
# Maaza                                          2850.0
# Minute Maid Orange Juice                       3850.0
# Parle Agros Appy Fizz                          1050.0
# REAL Guava Juice                               2250.0
# Real Pomegranate Juice                         2550.0
# Tropicano Guava Juice                          3650.0
# Tropicano Pomegranate Juice                    1750.0
#
#                                                  Product Assortment Key  Week  \
# Product
# BNatural Pomegranate Juice    BNatural Pomegranate Juice            MD1     1
# Maaza                                             Maaza             MD1     1
# Minute Maid Orange Juice        Minute Maid Orange Juice            MD1     1
# Parle Agros Appy Fizz              Parle Agros Appy Fizz            MD1     1
# REAL Guava Juice                        REAL Guava Juice            MD1     1
# Real Pomegranate Juice            Real Pomegranate Juice            MD1     1
# Tropicano Guava Juice              Tropicano Guava Juice            MD1     1
# Tropicano Pomegranate Juice  Tropicano Pomegranate Juice            MD1     1
#
#                               Validity (K,D,O)  Normalized Sales  Profit  \
# Product
# BNatural Pomegranate Juice  2023-01-01       D          0.142857  1250.0
# Maaza                       2023-01-01       K          0.285714  2050.0
# Minute Maid Orange Juice    2023-01-01       K          1.000000  2550.0
# Parle Agros Appy Fizz       2023-01-01       K          0.857143  8050.0
# REAL Guava Juice            2023-01-01       K          0.428571  1250.0
# Real Pomegranate Juice      2023-01-01       K          0.857143  1550.0
# Tropicano Guava Juice       2023-01-01       K          0.857143  2450.0
# Tropicano Pomegranate Juice 2023-01-01       D          0.000000  1150.0
#
#                              Normalized Profit  Ranking Key
# Product
# BNatural Pomegranate Juice            0.014493     0.078675
# Maaza                                 0.130435     0.208075
# Minute Maid Orange Juice              0.202899     0.601449
# Parle Agros Appy Fizz                 1.000000     0.928571
# REAL Guava Juice                      0.014493     0.221532
# Real Pomegranate Juice                0.057971     0.457557
# Tropicano Guava Juice                 0.188406     0.522774
# Tropicano Pomegranate Juice           0.000000     0.000000

# %%
df = df2_agg

# %%
df
# Out:
#                              Sales per Week  Retail Cost per Week  \
# Product
# BNatural Pomegranate Juice            160.0                3100.0
# Maaza                                 170.0                4900.0
# Minute Maid Orange Juice              220.0                6400.0
# Parle Agros Appy Fizz                 210.0                9100.0
# REAL Guava Juice                      180.0                3500.0
# Real Pomegranate Juice                210.0                4100.0
# Tropicano Guava Juice                 210.0                6100.0
# Tropicano Pomegranate Juice           150.0                2900.0
#
#                              Production Cost per Week  \
# Product
# BNatural Pomegranate Juice                     1850.0
# Maaza                                          2850.0
# Minute Maid Orange Juice                       3850.0
# Parle Agros Appy Fizz                          1050.0
# REAL Guava Juice                               2250.0
# Real Pomegranate Juice                         2550.0
# Tropicano Guava Juice                          3650.0
# Tropicano Pomegranate Juice                    1750.0
#
#                                                  Product Assortment Key  Week  \
# Product
# BNatural Pomegranate Juice    BNatural Pomegranate Juice            MD1     1
# Maaza                                             Maaza             MD1     1
# Minute Maid Orange Juice        Minute Maid Orange Juice            MD1     1
# Parle Agros Appy Fizz              Parle Agros Appy Fizz            MD1     1
# REAL Guava Juice                        REAL Guava Juice            MD1     1
# Real Pomegranate Juice            Real Pomegranate Juice            MD1     1
# Tropicano Guava Juice              Tropicano Guava Juice            MD1     1
# Tropicano Pomegranate Juice  Tropicano Pomegranate Juice            MD1     1
#
#                               Validity (K,D,O)  Normalized Sales  Profit  \
# Product
# BNatural Pomegranate Juice  2023-01-01       D          0.142857  1250.0
# Maaza                       2023-01-01       K          0.285714  2050.0
# Minute Maid Orange Juice    2023-01-01       K          1.000000  2550.0
# Parle Agros Appy Fizz       2023-01-01       K          0.857143  8050.0
# REAL Guava Juice            2023-01-01       K          0.428571  1250.0
# Real Pomegranate Juice      2023-01-01       K          0.857143  1550.0
# Tropicano Guava Juice       2023-01-01       K          0.857143  2450.0
# Tropicano Pomegranate Juice 2023-01-01       D          0.000000  1150.0
#
#                              Normalized Profit  Ranking Key
# Product
# BNatural Pomegranate Juice            0.014493     0.078675
# Maaza                                 0.130435     0.208075
# Minute Maid Orange Juice              0.202899     0.601449
# Parle Agros Appy Fizz                 1.000000     0.928571
# REAL Guava Juice                      0.014493     0.221532
# Real Pomegranate Juice                0.057971     0.457557
# Tropicano Guava Juice                 0.188406     0.522774
# Tropicano Pomegranate Juice           0.000000     0.000000

# %%
# df.rename(columns = {'Product':'Product Name'}, inplace = True)

# %%
from pulp import LpMaximize, LpProblem, LpVariable, lpSum

# %%
excel_df = pd.read_excel("ProductDimensions.xlsx")
 
filtered_df = df[df['(K,D,O)'] == 'K']

# %%
filtered_df
# Out:
#                           Sales per Week  Retail Cost per Week  \
# Product
# Maaza                              170.0                4900.0
# Minute Maid Orange Juice           220.0                6400.0
# Parle Agros Appy Fizz              210.0                9100.0
# REAL Guava Juice                   180.0                3500.0
# Real Pomegranate Juice             210.0                4100.0
# Tropicano Guava Juice              210.0                6100.0
#
#                           Production Cost per Week                   Product  \
# Product
# Maaza                                       2850.0                    Maaza
# Minute Maid Orange Juice                    3850.0  Minute Maid Orange Juice
# Parle Agros Appy Fizz                       1050.0     Parle Agros Appy Fizz
# REAL Guava Juice                            2250.0          REAL Guava Juice
# Real Pomegranate Juice                      2550.0    Real Pomegranate Juice
# Tropicano Guava Juice                       3650.0     Tropicano Guava Juice
#
#                          Assortment Key  Week   Validity (K,D,O)  \
# Product
# Maaza                               MD1     1 2023-01-01       K
# Minute Maid Orange Juice            MD1     1 2023-01-01       K
# Parle Agros Appy Fizz               MD1     1 2023-01-01       K
# REAL Guava Juice                    MD1     1 2023-01-01       K
# Real Pomegranate Juice              MD1     1 2023-01-01       K
# Tropicano Guava Juice               MD1     1 2023-01-01       K
#
#                           Normalized Sales  Profit  Normalized Profit  \
# Product
# Maaza                             0.285714  2050.0           0.130435
# Minute Maid Orange Juice          1.000000  2550.0           0.202899
# Parle Agros Appy Fizz             0.857143  8050.0           1.000000
# REAL Guava Juice                  0.428571  1250.0           0.014493
# Real Pomegranate Juice            0.857143  1550.0           0.057971
# Tropicano Guava Juice             0.857143  2450.0           0.188406
#
#                           Ranking Key
# Product
# Maaza                        0.208075
# Minute Maid Orange Juice     0.601449
# Parle Agros Appy Fizz        0.928571
# REAL Guava Juice             0.221532
# Real Pomegranate Juice       0.457557
# Tropicano Guava Juice        0.522774

# %%
excel_df
# Out:
#    Product ID                 Product Name  Height (cm)  Width (cm)  \
# 0        P001   BNatural Pomegranate Juice         20.3         7.6
# 1        P002       Real Pomegranate Juice         20.3         7.2
# 2        P003                     Horlicks         20.3        10.2
# 3        P004             Alphonso Mangoes         10.2         7.4
# 4        P005                        Parle         15.2         7.8
# 5        P006                    Britannia         15.2         7.9
# 6        P007  Tropicano Pomegranate Juice         20.3         7.3
# 7        P008             Totapuri Mangoes         12.7         7.2
# 8        P009                     Sunfeast         15.2         7.6
# 9        P010     Minute Maid Orange Juice         20.3         7.7
# 10       P011             REAL Guava Juice         20.3         7.1
# 11       P012                   Priya Gold         15.2         7.6
# 12       P013                 Unibic Foods         15.2         7.2
# 13       P014               Neelam Mangoes         10.2         7.6
# 14       P015                   Blue Berry          5.1        10.2
# 15       P016        Tropicano Guava Juice         20.3         7.6
# 16       P017                   Strawberry          5.1        10.1
# 17       P018                    Cranberry          5.1        10.2
# 18       P019                   Gala Apple          7.6         7.8
# 19       P020                       Maaza          20.3         7.4
# 20       P021        Parle Agros Appy Fizz         20.3         7.6
#
#     Depth (cm)
# 0          7.6
# 1          7.6
# 2         10.2
# 3          7.6
# 4          5.1
# 5          5.1
# 6          7.6
# 7          7.6
# 8          5.1
# 9          7.6
# 10         7.6
# 11         5.1
# 12         5.1
# 13         7.6
# 14        10.2
# 15         7.6
# 16        10.2
# 17        10.2
# 18         7.6
# 19         7.6
# 20         7.6

# %%
# Assuming excel_df is loaded from Excel
excel_df = pd.read_excel("productDimensions.xlsx")  # Adjust the filename as needed
filtered_df = filtered_df.reset_index(drop=True)
# Merge DataFrames on the 'Product' column
merged_df = pd.merge(filtered_df, excel_df, left_on='Product', right_on='Product Name')

# %%
merged_df
# Out:
#    Sales per Week  Retail Cost per Week  Production Cost per Week  \
# 0           170.0                4900.0                    2850.0
# 1           220.0                6400.0                    3850.0
# 2           210.0                9100.0                    1050.0
# 3           180.0                3500.0                    2250.0
# 4           210.0                4100.0                    2550.0
# 5           210.0                6100.0                    3650.0
#
#                     Product Assortment Key  Week   Validity (K,D,O)  \
# 0                    Maaza             MD1     1 2023-01-01       K
# 1  Minute Maid Orange Juice            MD1     1 2023-01-01       K
# 2     Parle Agros Appy Fizz            MD1     1 2023-01-01       K
# 3          REAL Guava Juice            MD1     1 2023-01-01       K
# 4    Real Pomegranate Juice            MD1     1 2023-01-01       K
# 5     Tropicano Guava Juice            MD1     1 2023-01-01       K
#
#    Normalized Sales  Profit  Normalized Profit  Ranking Key Product ID  \
# 0          0.285714  2050.0           0.130435     0.208075       P020
# 1          1.000000  2550.0           0.202899     0.601449       P010
# 2          0.857143  8050.0           1.000000     0.928571       P021
# 3          0.428571  1250.0           0.014493     0.221532       P011
# 4          0.857143  1550.0           0.057971     0.457557       P002
# 5          0.857143  2450.0           0.188406     0.522774       P016
#
#                Product Name  Height (cm)  Width (cm)  Depth (cm)
# 0                    Maaza          20.3         7.4         7.6
# 1  Minute Maid Orange Juice         20.3         7.7         7.6
# 2     Parle Agros Appy Fizz         20.3         7.6         7.6
# 3          REAL Guava Juice         20.3         7.1         7.6
# 4    Real Pomegranate Juice         20.3         7.2         7.6
# 5     Tropicano Guava Juice         20.3         7.6         7.6

# %%
profits = merged_df['Profit'].values
heights = merged_df['Height (cm)'].values
widths = merged_df['Width (cm)'].values
depths = merged_df['Depth (cm)'].values
products = merged_df['Product'].values

# %%
volumes = heights * widths * depths

# %%
prob = LpProblem(
"Maximize_Profit"
, LpMaximize)

# %%
units = LpVariable.dicts(
"Units"
, products, lowBound=0, cat=
'Integer'
)

# %%
prob += lpSum([units[product] * profits[i] for i, product in enumerate(products)])

# %%
prob += lpSum([units[product] * volumes[i] for i, product in enumerate(products)]) <= shelf_volume
 
# Add a constraint to ensure that at least 1 unit of each product is included
for i, product in enumerate(products):
    prob += units[product] >= 1

# %%
# Add constraints to balance the number of units across products
# For example, ensure no single product has more than 10 times the units of another product
for i in range(len(products)):
    for j in range(len(products)):
        prob += units[products[i]] <= 10 * units[products[j]]

# %%
# Solve the problem
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/fs/zvq11zm97ps2908z0gl0wpyr0000gn/T/8d569c6cca70488cb183d2c3e5821bcc-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/fs/zvq11zm97ps2908z0gl0wpyr0000gn/T/8d569c6cca70488cb183d2c3e5821bcc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 48 COLUMNS
# At line 145 RHS
# At line 189 BOUNDS
# At line 196 ENDATA
# Problem MODEL has 43 rows, 6 columns and 78 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 777376 - 0.00 seconds
# Cgl0004I processed model has 31 rows, 6 columns (6 integer (0 of which binary)) and 66 elements
# Cutoff increment increased from 1e-05 to 49.9999
# Cbc0012I Integer solution of -743200 found by DiveCoefficient after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0012I Integer solution of -764850 found by DiveCoefficient after 22 iterations and 0 nodes (0.02 seconds)
# Cbc0031I 5 added rows had average density of 4
# Cbc0013I At root node, 5 cuts changed objective from -777376.38 to -764850 in 9 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 25 row cuts average 2.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 21 row cuts average 2.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -764850.0000000001, took 22 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -777376 to -764850
# Probing was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 9 times and created 25 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 9 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 9 times and created 21 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                764850.00000000
# Enumerated nodes:               0
# Total iterations:               22
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
# 1

# %%
if LpStatus[prob.status] != 'Optimal':
    print(f"Optimization problem did not find an optimal solution. Status: {LpStatus[prob.status]}")
 
# Collect the results
results = []
 
for i, product in enumerate(products):
    results.append({
        'Product': product,
        'Units': units[product].varValue,
        'Profit': units[product].varValue * profits[i]
    })

# %%
results_df = pd.DataFrame(results)

# %%
results_df
# Out:
#                     Product  Units    Profit
# 0                    Maaza     9.0   18450.0
# 1  Minute Maid Orange Juice    9.0   22950.0
# 2     Parle Agros Appy Fizz   84.0  676200.0
# 3          REAL Guava Juice    9.0   11250.0
# 4    Real Pomegranate Juice    9.0   13950.0
# 5     Tropicano Guava Juice    9.0   22050.0

# %%
results_df = results_df[results_df[
'Units'
] > 0]

# %%
total_used_volume = sum(results_df['Units'] * volumes)
print(f"Total used volume: {total_used_volume} cm^3 out of {shelf_volume} cm^3")
# Out:
# Total used volume: 149867.592 cm^3 out of 150000 cm^3
